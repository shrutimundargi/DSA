# %% [markdown]
# # Tree DFS
#
# Tree is a graph which is
#
#
# *   Undirected
# *   Acyclic
# *   nodes can contain any datatype values
#
# ## When to use:
#
#
# *   Tree is balanced or has low branching factor, DFS provides efficient explorations due to less backtracking
# *   Solutions is likely near leaves
# *   Components of solution are in the path from root to leaves
#
# ## Common Problems:
# *  Find depth of tree
# *  Finding values in a given range
# *  Syntax trees
#
# ## Traversal orders:
#
# ![WhatsApp Image 2025-08-18 at 14.03.37.jpeg](data:image/jpeg;base64,...)
#
# ![WhatsApp Image 2025-08-18 at 14.03.36 (1).jpeg](data:image/jpeg;base64,...)
#
# ![WhatsApp Image 2025-08-18 at 14.03.36.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Given the root of a binary tree, return its maximum depth.
#
# A binary tree's maximum depth is the number of nodes along the longest path from the root node down to the farthest leaf node.

# %%
#recursion
if not root:
  return 0
return 1+max(self.maxDepth(root.left), self.maxDepth(root.right))

# %%
#iteration

stack = [[root, 1]]
res = 0

while stack:
  node, depth = stack.pop()

  if node:
    res = max(res, depth)
    stack.append([node.left, depth + 1])
    stack.append([node.right, depth + 1])

  return res

# %% [markdown]
# ## Consider all the leaves of a binary tree, from left to right order, the values of those leaves form a leaf value sequence.
#
# For example, in the given tree above, the leaf value sequence is (6, 7, 4, 9, 8).
#
# Two binary trees are considered leaf-similar if their leaf value sequence is the same.
#
# Return true if and only if the two given trees with head nodes root1 and root2 are leaf-similar.

# %%
class Solution:
    def leafSimilar(self, root1: Optional[TreeNode], root2: Optional[TreeNode]) -> bool:

        return self.leaf(root1) == self.leaf(root2)


    def leaf(self, root):
        if not root:
            return []
        if not (root.left or root.right):
            return [root.val]

        return self.leaf(root.left) + self.leaf(root.right)
